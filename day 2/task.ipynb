# %%
#course checker
python_class = {"Rahul", "Priya", "Arjun", "Sneha", "Karan"}
java_class = {"Priya", "Arjun", "Vikram", "Neha"}
ml_class = {"Sneha", "Vikram", "Rahul", "Divya"}
for i in python_class:
    if i  in java_class:
        print(i)
print("______________")

a=set()
for i in python_class:
    for j in java_class:
        for k in ml_class:
            a.add(i)
            a.add(j)
            a.add(k)
print(a)
print("______________")


for i in python_class:
    if i not in java_class:
        if i not in ml_class:
            print(i)
print("______________")

for i in python_class:
    for j in java_class:
        for k in ml_class:
            if i==j==k:
                print(i)
else:
    print("nobody")
# Out:
# Priya
# Arjun
# ______________
# {'Rahul', 'Priya', 'Arjun', 'Neha', 'Vikram', 'Karan', 'Sneha', 'Divya'}
# ______________
# Karan
# ______________
# nobody
